# %% [markdown]
# <a href="https://colab.research.google.com/github/girishkarhana/python/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '2.2.2'

# %%
number_series= pd.Series([1,2,3,4,5])
number_series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
number_series= pd.Series([1,2,3,4,5], index=['a','b','c','d','e'], name='Number')
number_series
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: Number, dtype: int64

# %%
print(number_series[0])
print(number_series['a'])
# Out:
# 1
# 1
# <ipython-input-415-43cc7e55b50e>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(number_series[0])

# %%
print(number_series)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: Number, dtype: int64

# %%
some_2D_array = np.random.randint(4,6,(3,4))
first_dataframe = pd.DataFrame(some_2D_array, columns=['AAA','BBB','CCC','DDD'])
first_dataframe
# Out:
#    AAA  BBB  CCC  DDD
# 0    4    4    5    5
# 1    5    5    4    5
# 2    4    5    4    5

# %%
import pandas as pd
another_dataframe = pd.DataFrame(some_2D_array, columns=['AAA','BBB','CCC','DDD'], index=['First','Second','Third'])
another_dataframe
# Out:
#         AAA  BBB  CCC  DDD
# First     4    4    5    5
# Second    5    5    4    5
# Third     4    5    4    5

# %%
list_og_lists=[['Boo',10], ['Baa',20], ['bee',30]]


df=pd.DataFrame(list_og_lists, columns=['Name','Age'])
df
# Out:
#   Name  Age
# 0  Boo   10
# 1  Baa   20
# 2  bee   30

# %%
employee_dict = {'Employee Name':['Boo','Baa','bee'], 'Income':[100000,200000,300000]}


#Create DataFrame and then print it
employee_df = pd.DataFrame(employee_dict)
employee_df
# Out:
#   Employee Name  Income
# 0           Boo  100000
# 1           Baa  200000
# 2           bee  300000

# %%
series_dict = {'First Series':pd.Series([1,2,3,4,5]),
               'Second Series':pd.Series([10,20,30,40,50])}


df=pd.DataFrame(series_dict)
df
# Out:
#    First Series  Second Series
# 0             1             10
# 1             2             20
# 2             3             30
# 3             4             40
# 4             5             50

# %%
lists_of_dicts=[{'A':1,'B':2,'C':3}, {'A':10,'B':20,'C':30}]


lists_of_dicts=[{'A':1,'B':2,'C':3}, {'A':10,'B':20,'C':30}]
df = pd.DataFrame(lists_of_dicts)
df
# Out:
#     A   B   C
# 0   1   2   3
# 1  10  20  30

# %%
list_of_dicts = [{'A':2,'B':3}, {'A':10,'B':20,'c':30}]
df = pd.DataFrame(list_of_dicts, index = ['First', 'Second'])
df
# Out:
#          A   B     c
# First    2   3   NaN
# Second  10  20  30.0

# %%
actor_names = ['Tom Cruise','Tom Hanks','Brad Pitt']
actor_ages = [40,38,42,np.nan]
list_of_tuples = list(zip(actor_names, actor_ages))

# %%
list_of_tuples = list(zip(actor_names, actor_ages))

actor_df = pd.DataFrame(list_of_tuples, columns=['Name','Age'])
actor_df
# Out:
#          Name  Age
# 0  Tom Cruise   40
# 1   Tom Hanks   38
# 2   Brad Pitt   42

# %%
list(actor_df.index)
# Out:
# [0, 1, 2]

# %%
our_array = np.random.randn(3,5)
df = pd.DataFrame(our_array, columns=['A','B','C','D','E'])
df
# Out:
#           A         B         C         D         E
# 0 -0.148921  1.339403  1.152255  1.630698  1.231634
# 1  0.380052  0.122679  0.780064  2.521555  0.664932
# 2  2.585766  2.120569 -0.474443  0.827915  1.221190

# %%
df.head()
# Out:
#           A         B         C         D         E
# 0 -0.148921  1.339403  1.152255  1.630698  1.231634
# 1  0.380052  0.122679  0.780064  2.521555  0.664932
# 2  2.585766  2.120569 -0.474443  0.827915  1.221190

# %%
df.head(1)
# Out:
#           A         B         C         D         E
# 0 -0.148921  1.339403  1.152255  1.630698  1.231634

# %%
df.tail()
# Out:
#           A         B         C         D         E
# 0 -0.148921  1.339403  1.152255  1.630698  1.231634
# 1  0.380052  0.122679  0.780064  2.521555  0.664932
# 2  2.585766  2.120569 -0.474443  0.827915  1.221190

# %%
list(df.columns)
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
actor_df
# Out:
#          Name  Age
# 0  Tom Cruise   40
# 1   Tom Hanks   38
# 2   Brad Pitt   42

# %%
actor_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
actor_df
# Out:
#          Name  Age
# 0  Tom Cruise   40
# 1   Tom Hanks   38
# 2   Brad Pitt   42

# %%
df1=actor_df.rename(columns={'Name':'Actor Name','Age':'Actor Age'}, inplace=False)
df1
# Out:
#    Actor Name  Actor Age
# 0  Tom Cruise         40
# 1   Tom Hanks         38
# 2   Brad Pitt         42

# %%
employee_df
# Out:
#   Employee Name  Income
# 0           Boo  100000
# 1           Baa  200000
# 2           bee  300000

# %%
employee_df.rename(columns = {'Employee Name':'Name','Income':'($)'}, inplace=True)
employee_df
# Out:
#   Name     ($)
# 0  Boo  100000
# 1  Baa  200000
# 2  bee  300000

# %%
employee_df = employee_df.rename({'Employee Name':'Name','Income':'($)'}, axis=1)
employee_df
# Out:
#   Name     ($)
# 0  Boo  100000
# 1  Baa  200000
# 2  bee  300000
